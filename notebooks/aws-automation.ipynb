# %% [markdown]
# # AWS Automation Examples\nThis notebook shows simple boto3 examples (run locally with AWS credentials).

# %%
import boto3
ec2 = boto3.client('ec2')
print('EC2 client configured')

# %%
# List instances
resp = ec2.describe_instances()
print(len(resp.get('Reservations', [])))
